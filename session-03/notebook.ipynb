# %% [markdown]
# # Session 3: What Models Can't Do
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/buildLittleWorlds/level-2-course-material/blob/main/session-03/notebook.ipynb)
#
# Tonight we close Act I: The Old Way. This notebook uses real news headlines to show why classification — sorting text into buckets — hits a fundamental wall.

# %%
# !pip install -q transformers torch
from transformers import pipeline
print("Setup complete!")

# %% [markdown]
# ## Story So Far
#
# **Session 1:** We learned classification. Give a model text, it sorts it into buckets. Simple. Powerful. Wrong more often than we thought.
#
# **Session 2:** We discovered that different models — trained differently, on different data — give different answers. A text that one model calls positive, another calls negative. The model isn't answering a question. It's showing us its training data.
#
# **Session 3 (tonight):** We apply these models to real news headlines and watch them fail in predictable ways. Not because the models are bad. Because classification itself has a limit. You can't sort meaning into buckets when the meaning doesn't fit.
#
# By the end of tonight, you'll see the wall. And tomorrow, we start building the bridge over it.

# %% [markdown]
# ## Load Models
#
# We'll load two models: a sentiment classifier (positive/negative) and a zero-shot classifier that can use ANY categories you give it.

# %%
model_sentiment = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")
print("Sentiment model loaded (positive / negative)")

model_zeroshot = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
print("Zero-shot model loaded (classifies into ANY labels you define)")
print()
print("Both models ready. Let's break them with real news.")

# %% [markdown]
# ## Failure Mode 1: Tone Deafness
#
# The model misses meaning that IS there.
#
# In news, this happens constantly: measured language about disasters, positive-sounding words describing negative outcomes, professional calm masking crisis. The model reads the words but not the story behind them.

# %%
tone_deaf_headlines = [
    "Rescue crews successfully locate survivors trapped in flood zone",
    "Efficiency gains lead to workforce reduction across tech sector",
    "Record-breaking temperatures bring crowds to city beaches",
    "Authorities restore calm after overnight protests in capital",
]

print("TONE DEAFNESS TEST: Headlines Where Words Don't Match Reality")
print("=" * 60)
for headline in tone_deaf_headlines:
    result = model_sentiment(headline)[0]
    zs = model_zeroshot(headline, ["good news", "bad news"])
    print(f'\n"{headline}"')
    print(f"  Sentiment: {result['label']} ({result['score']:.0%})")
    print(f"  Zero-shot: {zs['labels'][0]} ({zs['scores'][0]:.0%})")

# %% [markdown]
# ### What Happened?
#
# **\"Rescue crews successfully locate survivors\"** — The word \"successfully\" and \"locate\" and \"survivors\" are positive. The model scores it positive. But context: there's a flood. People are trapped. Survival in a disaster is not good news; it's the tragedy averted at the last moment.
#
# **\"Efficiency gains lead to workforce reduction\"** — \"Efficiency\" and \"gains\" sound like progress. The model might score it positive. But the story is layoffs. The people impacted don't experience this as a gain.
#
# **\"Record-breaking temperatures\"** — Records sound impressive. Positive. Except if the record is dangerous (climate crisis). The model sees the superlative, not the threat.
#
# **\"Authorities restore calm\"** — \"Restore\" and \"calm\" are peaceful words. But the story is protests — disagreement, conflict, unheard demands.
#
# The model reads words. It doesn't read the story behind them.

# %% [markdown]
# ## Failure Mode 2: Emotional Flattening
#
# The model oversimplifies meaning that's complex.
#
# Real news often describes genuinely multi-faceted situations: joy mixed with anxiety. Hope tangled with fear. Progress shadowed by loss. The model has to rank one label on top — even when the story is both and neither.

# %%
complex_headlines = [
    "Peace deal signed amid ongoing border tensions and refugee crisis",
    "New climate policy praised by scientists but slammed by industry leaders",
    "Historic school reopening brings joy and anxiety to parents",
    "Economy grows for third quarter while inequality gap widens",
]

print("EMOTIONAL FLATTENING TEST: Headlines That Are Genuinely Both")
print("=" * 60)
for headline in complex_headlines:
    result = model_sentiment(headline)[0]
    zs = model_zeroshot(headline, ["hopeful", "worrying", "mixed signals"])
    print(f'\n"{headline}"')
    print(f"  Sentiment: {result['label']} ({result['score']:.0%})")
    print(f"  Zero-shot: {zs['labels'][0]} ({zs['scores'][0]:.0%}), "
          f"{zs['labels'][1]} ({zs['scores'][1]:.0%}), "
          f"{zs['labels'][2]} ({zs['scores'][2]:.0%})")

# %% [markdown]
# ### What Happened?
#
# Look at the zero-shot confidence spread. When you see scores like 42% hopeful, 38% worrying, 20% mixed signals — what is the model doing?
#
# One interpretation: the model is uncertain.
#
# Another: the model is correctly recognizing that the headline is genuinely about both hope and worry. But because it's a classifier, it has to pick a winner. It can't say \"this story is really about complexity.\" It can only rank the buckets and hand you the top one.
#
# Real events are often genuinely mixed. A peace deal that doesn't end the underlying conflict. A climate policy that helps some people and hurts others. The model isn't confused. The story is actually, fundamentally complex. And the model's design forces it to flatten that complexity into a single label.

# %% [markdown]
# ## Failure Mode 3: Anthropomorphic Projection
#
# The model invents meaning that ISN'T there.
#
# Journalists write with metaphors. Markets \"panic.\" Storms \"rage.\" The economy \"struggles.\" These are figures of speech. No actual market is feeling fear. No storm is feeling anger. But because the model learned these metaphors from human writing about human emotions, it treats the words as if there's an agent having a feeling.

# %%
metaphor_headlines = [
    "Markets panic as trade talks stall between major economies",
    "Storm rages across southern coastline for third consecutive day",
    "Housing market shows signs of fatigue after year-long surge",
    "River reclaims its natural floodplain after dam removal",
]

print("ANTHROPOMORPHIC PROJECTION TEST: Who Is Feeling These Emotions?")
print("=" * 60)
for headline in metaphor_headlines:
    result = model_sentiment(headline)[0]
    zs = model_zeroshot(headline, ["emotional", "factual reporting"])
    print(f'\n"{headline}"')
    print(f"  Sentiment: {result['label']} ({result['score']:.0%})")
    print(f"  Zero-shot (emotional vs factual): {zs['labels'][0]} ({zs['scores'][0]:.0%})")

# %% [markdown]
# ### What Happened?
#
# **\"Markets panic\"** — Markets don't panic. Panic is a human emotion. But the word \"panic\" co-occurs with negative sentiment in training data, so the model treats it as a negative signal.
#
# **\"Storm rages\"** — Storms don't rage with anger. Rage is an emotion. But \"rage\" is lexically associated with intensity and negativity, so the model reads it as negative.
#
# **\"Housing market shows signs of fatigue\"** — Fatigue is exhaustion, a feeling. The housing market doesn't get tired. But \"fatigue\" is paired with negative sentiment in text, so the model treats the sentence as negative.
#
# **\"River reclaims its natural floodplain\"** — The river isn't *claiming* anything on purpose. \"Reclaim\" suggests intentional action and recovery, so the model might score this positive. But the story is often about flooding and damage — intention is invisible to the model.
#
# The model projects emotion onto non-human agents because the model learned these phrases from human language where metaphor and reality are tangled together.

# %% [markdown]
# ## Three Failure Modes: Summary
#
# | Failure Mode | What Happens | Example | Why |
# |---|---|---|---|
# | **Tone Deafness** | Model reads positive words in a negative story | \"Rescue crews successfully locate survivors\" (in a flood) | Training data associates words with labels; context is invisible |
# | **Emotional Flattening** | Model flattens genuinely complex stories into one label | \"Peace deal signed amid ongoing border tensions\" | Classifier design forces ranking; can't say \"both are true\" |
# | **Anthropomorphic Projection** | Model projects human emotions onto non-human agents | \"Markets panic,\" \"storms rage\" | Metaphorical language in training data gets treated as literal |
#
# All three point to the same wall: **classification treats text as a bag of signals to sort into buckets, when meaning often depends on context, complexity, and the gap between literal words and intended sense.**

# %% [markdown]
# ## Zero-Shot Classification: Can Better Categories Help?
#
# The sentiment model is locked into positive/negative. But what if we give the model *new* categories? What if we ask the model to classify headlines into buckets *we* define?
#
# This is **zero-shot classification**: you give the model a piece of text and a list of categories, and the model ranks how well each category fits — without ever seeing a training example of that category.
#
# **Question: Can better categories help the model avoid the three failure modes?**
#
# Let's try.

# %%
# CHANGE THESE CATEGORIES to whatever you want!
my_categories = ["neutral reporting", "editorial opinion", "clickbait"]

test_headlines = [
    "Rescue crews successfully locate survivors trapped in flood zone",
    "Markets panic as trade talks stall between major economies",
    "Peace deal signed amid ongoing border tensions and refugee crisis",
    "You Won't BELIEVE What Happened Next in Congress",
]

print(f"YOUR CATEGORIES: {my_categories}")
print("=" * 60)
for headline in test_headlines:
    result = model_zeroshot(headline, my_categories)
    scores = [f"{l} ({s:.0%})" for l, s in zip(result['labels'], result['scores'])]
    print(f'\n\"{headline}\"')
    print(f"  -> {', '.join(scores)}")

# %% [markdown]
# ## Reflect
#
# **Did your custom categories reveal something the sentiment model missed?**
#
# Or did the model make the same kinds of mistakes, just with different labels?
#
# Try this: what categories would you *want* to classify news into? Safety? Importance? Clarity? Complexity? Write them down, and then test them in the code above.

# %% [markdown]
# ## Design Your Own Categories
#
# Replace `my_custom_categories` with your own. What would make sense for *you* when reading news?
#
# Some ideas:
# - `[\"urgent\", \"routine\", \"developing\"]`
# - `[\"affects me directly\", \"affects others\", \"affects the world\"]`
# - `[\"action required\", \"information only\", \"opinion\"]`
# - Whatever you think matters.
#
# Then run the code and see what the model thinks.

# %%
# ===== EDIT THESE CATEGORIES =====
my_custom_categories = ["important", "not important", "unclear"]
# ==================================

test_headlines = [
    "Rescue crews successfully locate survivors trapped in flood zone",
    "Markets panic as trade talks stall between major economies",
    "Peace deal signed amid ongoing border tensions and refugee crisis",
    "Housing market shows signs of fatigue after year-long surge",
]

print(f"YOUR CATEGORIES: {my_custom_categories}")
print("=" * 60)
for headline in test_headlines:
    result = model_zeroshot(headline, my_custom_categories)
    scores = [f"{l} ({s:.0%})" for l, s in zip(result['labels'], result['scores'])]
    print(f'\n\"{headline}\"')
    print(f"  -> {', '.join(scores)}")
    print(f"     Does this match your instinct?")

# %% [markdown]
# ## The Old Way: What It's Good For, Where It Breaks
#
# ### The Pipeline
#
# ```
# Text -> Model -> Label
# ```
#
# Classification works like an assembly line:
# 1. You have text (a tweet, a headline, a review).
# 2. You feed it to a model.
# 3. The model outputs a category: positive/negative, spam/not spam, urgent/routine.
# 4. You act on that category.
#
# ### What It's Good For
#
# - **High-volume sorting.** Filtering spam. Routing customer tickets. Tagging content.
# - **Consistent buckets.** When the boundary between categories is clear and unambiguous.
# - **Speed.** Classification models are fast and cheap.
#
# ### Where It Breaks
#
# - **When meaning depends on context** (tone deafness)
# - **When reality is genuinely complex** (emotional flattening)
# - **When language is metaphorical** (anthropomorphic projection)
# - **When the boundary between categories is fuzzy** (is this a feature or a bug?)
# - **When you need to understand *why*, not just which bucket** (the model never shows you its reasoning)
#
# News is one of the worst domains for classification — almost every headline triggers one of these failure modes. But so do customer feedback, legal documents, medical records, and any text where stakes are high and meaning matters.
#
# ### The Bridge
#
# Tomorrow, Session 4: we start learning a new way. One that doesn't force meaning into buckets. One that shows you the reasoning. One that can say \"I don't know\" instead of lying confidently.
#
# For now: you've seen the wall.

# %% [markdown]
# ## Vocabulary: Key Concepts for Session 3
#
# | Term | Definition |
# |---|---|
# | **Classification** | Sorting text into predefined categories. The model reads the input and assigns it to one bucket. |
# | **Adversarial Input** | Text designed to reveal what a model *can't* do. News headlines are naturally adversarial to classification. |
# | **API** | Application Programming Interface. How you talk to a model (in this notebook, via HuggingFace Transformers). |
# | **Zero-Shot Classification** | Classification where the model has never seen training examples of the categories. You define the categories at runtime. |
# | **Tone Deafness** | When a model reads positive/negative words but misses the emotional meaning of the actual story. |
# | **Emotional Flattening** | When a model flattens genuinely complex, multi-faceted meaning into a single category. |
# | **Anthropomorphic Projection** | When a model treats metaphorical language ("markets panic") as literal emotion from a non-human agent. |
# | **Noise** | Information that doesn't carry meaning. In classification: the gap between what words say and what they mean. |
# | **Meaning Problem** | The core challenge: models are trained on statistical patterns in language, but meaning often lives in context, intention, and the gap between what's said and what's meant. |

# %% [markdown]
# ## Save Your Work to GitHub
#
# This notebook is part of **AI + Research Level 2**, a course on what language models can and can't do.
#
# To save your work:
#
# 1. In Colab: **File -> Save a copy in GitHub**
# 2. Or download this notebook and commit it to your fork of [buildLittleWorlds/level-2-course-material](https://github.com/buildLittleWorlds/level-2-course-material)
# 3. Create a pull request with your experiments, reflections, or custom categories.
#
# ### What to Share
#
# - **Your custom categories** (Session 3 \"Design Your Own\")
# - **Headlines you found** that break the models in interesting ways
# - **Reflections**: Did the zero-shot model do better? Why or why not?
# - **Questions**: What would you want a model to do that classification can't?
#
# See you in Session 4.
