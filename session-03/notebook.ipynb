# %% [markdown]
# # Session 3: When Sarcasm Breaks Everything
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/buildLittleWorlds/level-2-sentiment-course/blob/main/session-03/notebook.ipynb)

# %%
# !pip install -q transformers torch
from transformers import pipeline
import re
print("Setup complete!")

# %% [markdown]
# ## What We Built Tonight
#
# We fed the Mood Meter **sarcasm, irony, and mixed signals** and watched it fail. Then we wrote a `clean_text()` function to fix what we could.
#
# The pattern: **MESSY INPUT** -> **clean_text()** -> **CLEANER INPUT** -> **MODEL** -> **OUTPUT**
#
# The model didn't get smarter -- we just gave it better input. But **tone** is not noise. Tone is meaning. And you can't clean meaning.

# %% [markdown]
# ## Load the Model

# %%
analyzer = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")
print("Model loaded!")

# %% [markdown]
# ## Before Cleaning: Sarcasm and Irony
#
# Run the model on sarcastic and ironic text. How does it handle tone?

# %%
# Sarcastic and ironic inputs -- the model will get these wrong
sarcastic_texts = [
    "Oh GREAT, another Monday. Just what I needed.",
    "I suppose getting into Harvard is okay.",
    "Per my last email, as I mentioned before, I'm happy to clarify.",
    "I'm fine. Everything is fine. This is fine.",
]

print("BEFORE CLEANING:")
print("=" * 50)
for text in sarcastic_texts:
    result = analyzer(text)[0]
    print(f"{result['label']} ({result['score']:.0%}) -- \"{text}\"")
    print()

# %% [markdown]
# **Observation:** Did the model catch the sarcasm? Or did it read the words literally?
#
# *Your observations:*

# %% [markdown]
# ## The clean_text() Function
#
# This function cleans up messy input **before** the model sees it. Run this cell to define it.

# %%
def clean_text(text):
    # 1. Strip leading/trailing whitespace
    text = text.strip()

    # 2. Collapse multiple spaces into one
    text = re.sub(r' {2,}', ' ', text)

    # 3. Limit repeated characters ("sooooo" -> "soo")
    text = re.sub(r'(.)\1{2,}', r'\1\1', text)

    # 4. Remove emoji
    text = re.sub(
        r'[\U0001F600-\U0001F64F'
        r'\U0001F300-\U0001F5FF'
        r'\U0001F680-\U0001F6FF'
        r'\U00002600-\U000026FF]+',
        ' ', text
    )

    # 5. Normalize ALL CAPS to Title Case
    words = text.split()
    caps_count = sum(1 for w in words if w.isupper() and len(w) > 1)
    if caps_count > 3:
        text = text.title()

    # Clean up any extra spaces from cleaning
    text = re.sub(r' {2,}', ' ', text).strip()

    return text

print("clean_text() is ready!")

# %% [markdown]
# ## After Cleaning: Compare
#
# Run the same sarcastic text through `clean_text()` first, then through the model.

# %%
sarcastic_texts = [
    "Oh GREAT, another Monday. Just what I needed.",
    "I suppose getting into Harvard is okay.",
    "Per my last email, as I mentioned before, I'm happy to clarify.",
    "I'm fine. Everything is fine. This is fine.",
]

print("BEFORE vs. AFTER CLEANING:")
print("=" * 50)
for text in sarcastic_texts:
    cleaned = clean_text(text)
    r_before = analyzer(text)[0]
    r_after = analyzer(cleaned)[0]
    
    changed = "CHANGED!" if r_before['label'] != r_after['label'] else "same"
    
    print(f"Original: \"{text}\"")
    print(f"Cleaned:  \"{cleaned}\"")
    print(f"Before: {r_before['label']} ({r_before['score']:.0%})")
    print(f"After:  {r_after['label']} ({r_after['score']:.0%}) [{changed}]")
    print()

# %% [markdown]
# ## Experiments
#
# ### Experiment 1: Emoji Contradictions
#
# **Try this:** What happens when the emoji tells a different story than the words?

# %%
# Emoji contradictions -- the emoji and words disagree
emoji_texts = [
    "Worst day ever \U0001F602\U0001F389\U0001F480",
    "I'm so happy right now \U0001F62D\U0001F62D\U0001F62D",
    "Everything is great \U0001F525\U0001F480",
    "no literally I'm deceased this is the funniest thing \U0001F480\U0001F480\U0001F480",
]

for text in emoji_texts:
    cleaned = clean_text(text)
    r_before = analyzer(text)[0]
    r_after = analyzer(cleaned)[0]
    
    print(f"Original: \"{text}\"")
    print(f"Before cleaning: {r_before['label']} ({r_before['score']:.0%})")
    print(f"After cleaning:  {r_after['label']} ({r_after['score']:.0%})")
    print(f"Cleaned text: \"{cleaned}\"")
    print()

# %% [markdown]
# **Observation:** Did removing emoji change the model's reading? Was the change helpful or did it remove important information?
#
# *Your observations:*

# %% [markdown]
# ### Experiment 2: ALL CAPS Sarcasm
#
# **Try this:** Does normalizing ALL CAPS help the model, or does it lose the tone?

# %%
# ALL CAPS -- the caps ARE the tone
caps_texts = [
    "Yeah, I totally LOVE getting up at 5am. It's my FAVORITE thing.",
    "THIS IS ABSOLUTELY THE BEST DAY OF MY ENTIRE LIFE I AM SO HAPPY RIGHT NOW",
    "sure THIS IS TOTALLY FINE NOTHING TO SEE HERE EVERYTHING IS GREAT",
    "lolllll sure thing bestie whatever you say",
]

for text in caps_texts:
    cleaned = clean_text(text)
    r_before = analyzer(text)[0]
    r_after = analyzer(cleaned)[0]
    
    print(f"Original: \"{text}\"")
    print(f"Cleaned:  \"{cleaned}\"")
    print(f"Before: {r_before['label']} ({r_before['score']:.0%})")
    print(f"After:  {r_after['label']} ({r_after['score']:.0%})")
    print()

# %% [markdown]
# ### Experiment 3: The Unfixable Ones
#
# **Try this:** These are pure tone problems. No amount of cleaning will help. Why?

# %%
# Pure tone -- no noise to clean, just meaning the model can't read
tone_texts = [
    "Thanks for getting back to me.",
    "I will always love you.",
    "That's really interesting.",
    "I hope you have the day you deserve.",
    "No worries at all.",
]

for text in tone_texts:
    result = analyzer(text)[0]
    print(f"{result['label']} ({result['score']:.0%}) -- \"{text}\"")
    print()

# %% [markdown]
# **Observation:** Each of these could be sincere OR sarcastic depending on who's saying it and why. The model picks one reading. Could it ever be right?
#
# *Your observations:*

# %% [markdown]
# ### Experiment 4: Add Your Own Cleaning Step
#
# **Try this:** Edit the function below to add a new cleaning step. Ideas: handle hashtags, expand contractions, remove URLs.

# %%
def my_clean_text(text):
    # Start with the same steps as before
    text = text.strip()
    text = re.sub(r' {2,}', ' ', text)
    text = re.sub(r'(.)\1{2,}', r'\1\1', text)

    # YOUR NEW STEP HERE: try adding something!
    # Example: remove hashtags
    # text = re.sub(r'#(\w+)', r'\1', text)

    return text

# Test it
test = "#blessed soooo happy right now #goodvibes lolllll"
print(f"Before: {test}")
print(f"After:  {my_clean_text(test)}")

# %% [markdown]
# ### Experiment 5: Your Own Sarcastic Text
#
# **Try this:** Write something sarcastic or ironic that you'd actually text a friend. Test it with and without cleaning.

# %%
# Replace this with your own sarcastic text!
my_text = "Replace this with something sarcastic you'd actually text!"

cleaned = clean_text(my_text)
r_before = analyzer(my_text)[0]
r_after = analyzer(cleaned)[0]

print(f"Original: \"{my_text}\"")
print(f"Cleaned:  \"{cleaned}\"")
print(f"Before: {r_before['label']} ({r_before['score']:.0%})")
print(f"After:  {r_after['label']} ({r_after['score']:.0%})")
print()
print("Is this a noise problem or a tone problem?")

# %% [markdown]
# ## Challenge
#
# Find a text where `clean_text()` makes the result **better** AND a text where cleaning makes **no difference** (because the problem is tone, not noise). What does that tell you about the limits of data cleaning?
#
# ---
#
# **GitHub skill:** Upload this notebook to your `my-ai-portfolio` repo:
# 1. Go to your repo on github.com
# 2. Click **Add file** -> **Upload files**
# 3. Drag your `.ipynb` file and click **Commit changes**

# %% [markdown]
# ## Vocabulary
#
# | Term | Meaning |
# |------|--------|
# | **Data cleaning** | Preprocessing text to remove noise before the model sees it |
# | **Noise** | Stuff in the input that confuses the model (emoji, extra spaces, weird formatting) |
# | **Adversarial input** | Text deliberately designed to confuse or break a model |
# | **Tone** | The way something is said -- meaning that lives between the words |
# | **Feature engineering** | Transforming raw input into something a model can work with better |
# | **CLEAR Framework** | A structure for writing good prompts to AI coding assistants |
