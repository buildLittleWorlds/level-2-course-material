# %% [markdown]
# # Session 3: What Models Can't Do
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/buildLittleWorlds/level-2-course-material/blob/main/session-03/notebook.ipynb)
#
# Tonight we close **Act I: The Old Way**. This notebook walks through everything we've learned in Sessions 1–3 and shows why classification — sorting text into buckets — is real, useful work that hits a fundamental wall.

# %%
# !pip install -q transformers torch
from transformers import pipeline
import re
print("Setup complete!")

# %% [markdown]
# ## The Story So Far
#
# Here's what three sessions have taught us:
#
# **Session 1:** We fed text to a model and it said "positive" or "negative." That's **classification** — sorting into buckets from a fixed menu. It felt like magic.
#
# **Session 2:** We compared different models on the same text. Different training data = different answers. What a model can see depends on what it was trained to see.
#
# **Session 3 (tonight):** We break the models. Three different ways. And we discover that no matter how many labels, no matter how much cleaning — these models don't *understand*. They match patterns in words.
#
# This is what AI looked like for most of its history. Small models. Narrow tasks. Enormous human work. Let's see exactly where the wall is.

# %% [markdown]
# ## Load the Models
#
# We'll load two classification models — a simple 2-label model (positive/negative) and a more complex 6-emotion model — to see how each handles the same failures.

# %%
# A simple 2-label model (from Session 1)
model_simple = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english"
)
print("2-label model loaded (positive / negative)")

# A 6-emotion model (from Session 2)
model_emotion = pipeline(
    "text-classification",
    model="bhadresh-savani/distilbert-base-uncased-emotion",
    top_k=3
)
print("6-emotion model loaded (sadness, joy, love, anger, fear, surprise)")
print()
print("Both models ready. Let's break them.")

# %% [markdown]
# ---
#
# ## Failure Mode 1: Tone Deafness
#
# **The model misses meaning that's there.**
#
# Sarcasm says one thing and means the opposite. The words sound positive, but the meaning is negative. A human catches this instantly. Classification models read the words literally.

# %%
# The Sarcastic Narrator -- from our adversarial stories
sarcastic_lines = [
    "Monday morning arrived like a gift from the universe.",
    "The coffee maker had thoughtfully decided to stop working, because why would anyone need caffeine on a Monday?",
    "The bus pulled away just as she reached the stop, which was honestly perfect timing.",
    "Her inbox had 47 unread emails, each one a little treasure waiting to be discovered.",
]

print("TONE DEAFNESS TEST: The Sarcastic Narrator")
print("Every line below is sarcastic. The real feeling is NEGATIVE.")
print("=" * 60)
for line in sarcastic_lines:
    simple = model_simple(line)[0]
    emotion = model_emotion(line)[0]  # top prediction
    print(f'\n"{line}"')
    print(f"  2-label: {simple['label']} ({simple['score']:.0%})")
    print(f"  6-emotion: {emotion[0]['label']} ({emotion[0]['score']:.0%})")

# %% [markdown]
# **What happened?** The models probably read these as positive or joyful. But every line is dripping with sarcasm — the narrator is having a terrible day.
#
# The models aren't broken. They're doing exactly what they were trained to do: match word patterns to labels. The word "gift" maps to positive. "Perfect timing" maps to positive. The sarcastic meaning lives *between* the words, and classification models can't reach it.
#
# *Your observations:*

# %% [markdown]
# ---
#
# ## Failure Mode 2: Emotional Flattening
#
# **The model oversimplifies meaning that's complex.**
#
# Real life is full of mixed emotions. You can feel excited and terrified at the same time. Happy and sad in the same sentence. Classification models must pick one label — they flatten the complexity into a single bucket.

# %%
# The Mixed-Emotion Story -- from our adversarial stories
mixed_lines = [
    "The acceptance letter sat on the kitchen table, and she couldn't stop reading it.",
    "Her mother stood behind her, one hand on her shoulder, crying.",
    "They both knew what this meant: she'd be moving 2,000 miles away in August.",
    "That night, they celebrated with her favorite dinner, and nobody mentioned the empty chair that would be there next year.",
]

print("EMOTIONAL FLATTENING TEST: The Mixed-Emotion Story")
print("Every line has MULTIPLE emotions tangled together.")
print("=" * 60)
for line in mixed_lines:
    simple = model_simple(line)[0]
    emotion = model_emotion(line)
    top3 = emotion[0][:3]
    print(f'\n"{line}"')
    print(f"  2-label: {simple['label']} ({simple['score']:.0%})")
    print(f"  6-emotion top 3: {top3[0]['label']} ({top3[0]['score']:.0%}), "
          f"{top3[1]['label']} ({top3[1]['score']:.0%}), "
          f"{top3[2]['label']} ({top3[2]['score']:.0%})")

# %% [markdown]
# **What happened?** Each line carries joy *and* sadness *and* love *and* loss all at once. The 2-label model picks one side. The 6-emotion model might split its confidence a bit, but it still has to rank one emotion on top.
#
# The problem isn't the number of labels. Even 28 emotion categories can't capture "I'm thrilled about college but heartbroken about leaving home" as a single label. The *structure* of classification — one input, one label — flattens what's actually there.
#
# *Your observations:*

# %% [markdown]
# ---
#
# ## Failure Mode 3: Anthropomorphic Projection
#
# **The model invents meaning that isn't there.**
#
# What happens when you describe something with zero human emotion — a volcano, a river, a forest — and the model insists on finding feelings anyway?

# %%
# The Nature Story -- from our adversarial stories
nature_lines = [
    "The volcano had been dormant for three hundred years.",
    "When it finally erupted, the lava flowed southeast at twelve meters per hour.",
    "The nearby forest burned for nine days, and then the rain came.",
    "Within eighteen months, the first green shoots appeared in the ash.",
    "No humans lived within forty miles of the eruption.",
]

print("ANTHROPOMORPHIC PROJECTION TEST: The Nature Story")
print("There are NO human emotions here. Just geology and ecology.")
print("=" * 60)
for line in nature_lines:
    simple = model_simple(line)[0]
    emotion = model_emotion(line)
    top3 = emotion[0][:3]
    print(f'\n"{line}"')
    print(f"  2-label: {simple['label']} ({simple['score']:.0%})")
    print(f"  6-emotion top 3: {top3[0]['label']} ({top3[0]['score']:.0%}), "
          f"{top3[1]['label']} ({top3[1]['score']:.0%}), "
          f"{top3[2]['label']} ({top3[2]['score']:.0%})")

# %% [markdown]
# **What happened?** The models assigned emotions to volcanoes and forests. "Fear" for the eruption? "Sadness" for the burning forest? Those are *human* feelings that the model projects onto nature. The text describes physical processes — no creature in the story feels anything.
#
# This is the sneakiest failure because it *sounds* reasonable. Of course a burning forest is sad! But that's *your* feeling, not the text's meaning. The model was trained on human-written text about human emotions, so it sees human emotions everywhere — even when they aren't there.
#
# This is also a **false positive** in everything but name: the model confidently detects emotion in text that contains none.
#
# *Your observations:*

# %% [markdown]
# ---
#
# ## Can Cleaning Fix Any of This?
#
# In the first half of tonight's session, we built a `clean_text()` function. It fixes formatting problems — extra spaces, repeated characters, emoji, ALL CAPS. That's **noise**.
#
# But the three failure modes above aren't noise problems. They're **meaning** problems. Let's prove it.

# %%
def clean_text(text):
    """Clean up messy input before the model sees it."""
    text = text.strip()
    text = re.sub(r' {2,}', ' ', text)
    text = re.sub(r'(.)\1{2,}', r'\1\1', text)
    text = re.sub(
        r'[\U0001F600-\U0001F64F'
        r'\U0001F300-\U0001F5FF'
        r'\U0001F680-\U0001F6FF'
        r'\U00002600-\U000026FF]+',
        ' ', text
    )
    words = text.split()
    caps_count = sum(1 for w in words if w.isupper() and len(w) > 1)
    if caps_count > 3:
        text = text.title()
    text = re.sub(r' {2,}', ' ', text).strip()
    return text

print("clean_text() is ready.")

# %%
# Test: Does cleaning help with any of the three failure modes?
all_test_lines = {
    "Tone Deafness (sarcasm)": [
        "Monday morning arrived like a gift from the universe.",
        "Her inbox had 47 unread emails, each one a little treasure.",
    ],
    "Emotional Flattening (mixed)": [
        "The acceptance letter sat on the kitchen table, and she couldn't stop reading it.",
        "They celebrated with her favorite dinner, and nobody mentioned the empty chair.",
    ],
    "Anthropomorphic Projection (nature)": [
        "When it finally erupted, the lava flowed southeast at twelve meters per hour.",
        "The nearby forest burned for nine days, and then the rain came.",
    ],
}

print("DOES CLEANING HELP?")
print("=" * 60)
for category, lines in all_test_lines.items():
    print(f"\n--- {category} ---")
    for line in lines:
        cleaned = clean_text(line)
        r_before = model_simple(line)[0]
        r_after = model_simple(cleaned)[0]
        changed = "CHANGED" if r_before['label'] != r_after['label'] else "same"
        print(f'\n  "{line[:60]}..."' if len(line) > 60 else f'\n  "{line}"')
        print(f"  Before: {r_before['label']} ({r_before['score']:.0%})")
        print(f"  After:  {r_after['label']} ({r_after['score']:.0%}) [{changed}]")

print("\n" + "=" * 60)
print("Cleaning fixes NOISE (formatting, emoji, caps).")
print("It can't fix MEANING (sarcasm, mixed emotions, projection).")
print("That's the wall.")

# %% [markdown]
# ---
#
# ## The Three Failure Modes
#
# | Failure Mode | What Happens | Example | Fixable? |
# |---|---|---|---|
# | **Tone Deafness** | Model misses meaning that's present | Sarcasm read as positive | No — meaning problem |
# | **Emotional Flattening** | Model oversimplifies complex meaning | Joy + sadness → just "joy" | No — structural problem |
# | **Anthropomorphic Projection** | Model invents meaning that isn't there | Volcano → "fear" | No — training data problem |
#
# All three are **meaning problems**, not noise problems. No amount of data cleaning solves them. The problem isn't in the input — it's in what classification *is*.

# %% [markdown]
# ---
#
# ## Experiment: Noise vs. Meaning
#
# Now try your own inputs. Write one that's a **noise problem** (cleaning should help) and one that's a **meaning problem** (cleaning won't help).

# %%
# YOUR NOISE PROBLEM: messy formatting that cleaning can fix
noise_example = "THIS IS SOOOOO GREAT I LOVE IT!!!!!  \U0001F602\U0001F602\U0001F602"

# YOUR MEANING PROBLEM: clean text that the model still gets wrong
meaning_example = "I hope you have the day you deserve."

print("NOISE PROBLEM:")
cleaned = clean_text(noise_example)
r_before = model_simple(noise_example)[0]
r_after = model_simple(cleaned)[0]
print(f"  Original: \"{noise_example}\"")
print(f"  Cleaned:  \"{cleaned}\"")
print(f"  Before: {r_before['label']} ({r_before['score']:.0%})")
print(f"  After:  {r_after['label']} ({r_after['score']:.0%})")

print("\nMEANING PROBLEM:")
cleaned = clean_text(meaning_example)
r_before = model_simple(meaning_example)[0]
r_after = model_simple(cleaned)[0]
print(f"  Original: \"{meaning_example}\"")
print(f"  Cleaned:  \"{cleaned}\"")
print(f"  Before: {r_before['label']} ({r_before['score']:.0%})")
print(f"  After:  {r_after['label']} ({r_after['score']:.0%})")
print()
print("Did cleaning help the noise problem? The meaning problem?")

# %% [markdown]
# ---
#
# ## Experiment: More Labels, Same Wall?
#
# Does having 6 emotions instead of 2 labels help with any of the three failure modes? Let's check.

# %%
test_cases = [
    ("Tone Deafness", "Her inbox had 47 unread emails, each one a little treasure waiting to be discovered."),
    ("Emotional Flattening", "That night, they celebrated with her favorite dinner, and nobody mentioned the empty chair that would be there next year."),
    ("Anthropomorphic Projection", "The nearby forest burned for nine days, and then the rain came."),
]

print("MORE LABELS = MORE UNDERSTANDING?")
print("=" * 60)
for mode, text in test_cases:
    simple = model_simple(text)[0]
    emotion = model_emotion(text)
    top3 = emotion[0][:3]
    print(f"\n{mode}:")
    print(f'  "{text}"')
    print(f"  2-label:  {simple['label']} ({simple['score']:.0%})")
    print(f"  6-emotion: {top3[0]['label']} ({top3[0]['score']:.0%}), "
          f"{top3[1]['label']} ({top3[1]['score']:.0%}), "
          f"{top3[2]['label']} ({top3[2]['score']:.0%})")

print("\n" + "=" * 60)
print("More labels gives more detail, but the same fundamental failures.")
print("3 labels, 6, 7, 28 -- it's still just picking from a menu.")

# %% [markdown]
# *Did 6 emotions help? Or did the model make the same kinds of mistakes with more categories?*
#
# *Your observations:*

# %% [markdown]
# ---
#
# ## Experiment: Write Your Own Adversarial Input
#
# Design one input for each failure mode. Try to make the model fail as clearly as possible.

# %%
# Replace these with your own adversarial inputs!
my_sarcasm = "Replace this with something sarcastic."        # Should fool the model into POSITIVE
my_mixed = "Replace this with something bittersweet."         # Should have multiple emotions
my_nature = "Replace this with something about nature."       # Should have NO human emotions

my_tests = [
    ("Your sarcasm (tone deafness)", my_sarcasm),
    ("Your mixed emotion (flattening)", my_mixed),
    ("Your nature text (projection)", my_nature),
]

for label, text in my_tests:
    simple = model_simple(text)[0]
    emotion = model_emotion(text)
    top3 = emotion[0][:3]
    print(f"{label}:")
    print(f'  "{text}"')
    print(f"  2-label:  {simple['label']} ({simple['score']:.0%})")
    print(f"  6-emotion: {top3[0]['label']} ({top3[0]['score']:.0%}), "
          f"{top3[1]['label']} ({top3[1]['score']:.0%}), "
          f"{top3[2]['label']} ({top3[2]['score']:.0%})")
    print()

# %% [markdown]
# ---
#
# ## The Old Way: Sessions 1–3 in One Picture
#
# Here's what we've been doing for three weeks:
#
# ```
# TEXT  →  [clean it]  →  MODEL  →  LABEL
#                             │
#                     picks from a fixed menu
#                     (positive, negative, joy, sadness...)
# ```
#
# This is **classification**. It's real work. It's useful. Spam filters, content moderation, medical triage — classification powers all of these.
#
# But it has a wall:
#
# - It can't catch meaning that lives between the words (sarcasm, irony, tone)
# - It can't express more than one thing at a time (mixed emotions get flattened)
# - It sees what it was trained to see, even when it's not there (projection)
# - More labels don't fix these problems — they just give you more buckets to sort into
#
# For decades, this is what AI researchers spent their time doing. Cleaning data. Engineering features. Building narrow models for narrow tasks. And hitting this same wall, over and over.
#
# **Next week:** What if we stopped sorting into buckets? What if instead of choosing a label, a model could *write something new*?

# %% [markdown]
# ---
#
# ## Vocabulary
#
# | Term | Meaning |
# |------|--------|
# | **Classification** | AI that sorts inputs into categories from a fixed menu |
# | **Adversarial input** | Text deliberately designed to confuse or break a model |
# | **Tone deafness** | When a model misses meaning that's present (e.g., sarcasm) |
# | **Emotional flattening** | When a model oversimplifies complex meaning into one label |
# | **Anthropomorphic projection** | When a model invents human meaning that isn't there |
# | **Noise** | Formatting problems that can be cleaned (emoji, caps, extra spaces) |
# | **Meaning problem** | A comprehension failure that no amount of cleaning can fix |
# | **Data cleaning** | Preprocessing text to remove noise before the model sees it |
# | **False positive** | The model confidently detects something that isn't there |
# | **CLEAR Framework** | A structure for writing good prompts to AI coding assistants |
#
# ---
#
# **GitHub skill:** Upload this notebook to your `my-ai-portfolio` repo:
# 1. Go to your repo on github.com
# 2. Click **Add file** → **Upload files**
# 3. Drag your `.ipynb` file and click **Commit changes**
