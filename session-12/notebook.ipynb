# %% [markdown]
# # Session 12: Methodological Reflection and Portfolio Presentation
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/buildLittleWorlds/level-2-course-material/blob/main/session-12/notebook.ipynb)
#
# You built it. Now show it off.

# %% [markdown]
# ## Demo Day!
#
# Session 12 · Act III: Building and Reflecting
#
# Congratulations! You've spent eleven weeks building real AI tools.
#
# You started by feeding text to a mood-reading model. You broke models with sarcasm. You crossed the fork from classification to generation. You added controls, hit the wall, saw the breakthrough, confronted the cost, chained models into pipelines. You designed for humans, built from scratch, and iterated through peer feedback.
#
# Everything you created lives on the internet with a public URL that anyone can visit. Tonight you tell the story of that investigation.

# %% [markdown]
# ## Your Portfolio
#
# **My Hugging Face Profile:** ___(your HF username URL)___
#
# **My GitHub Profile:** ___(your GitHub profile URL)___
#
# ### Spaces I Built
#
# | Name | URL | What It Does |
# |------|-----|-------------|
# | | | |
# | | | |
# | | | |
# | | | |

# %% [markdown]
# ## My Research Question
#
# By Session 10, you chose a question and built a tool to investigate it.
#
# **What question were you investigating by the end of the course?**
#
# ___(fill in)___

# %% [markdown]
# ## My Hugging Face Collection
#
# Your HF Collection gathers the models, datasets, and Spaces you used across the course.
#
# **Collection URL:** ___(paste your HF Collection link)___
#
# **Number of items in my collection:** ___
#
# **Focus area of my collection** (e.g., image classifiers, text generators, bias testing tools):
#
# ___(fill in)___

# %% [markdown]
# ## My Research Journal
#
# Your Research Journal on GitHub tracks what you tried, what you found, and what surprised you.
#
# **GitHub Research Journal link:** ___(paste your repo link)___
#
# **Number of entries:** ___
#
# **Summary of my investigative thread** (what connects your entries?):
#
# ___(fill in)___

# %% [markdown]
# ## Research Methods I Used
#
# Check off every research method you practiced during the course:
#
# - [ ] **Comparative Analysis** (Session 2) — compared multiple models on same inputs
# - [ ] **Adversarial Testing** (Session 3) — found inputs that break models
# - [ ] **Baseline Comparison** (Session 4) — evaluated models side by side with ground truth
# - [ ] **Parameter Sweep** (Session 5) — systematically changed one variable at a time
# - [ ] **Generalization Testing** (Session 6) — tested models outside their training domain
# - [ ] **Fairness Audit** (Session 7) — designed paired tests for algorithmic bias
# - [ ] **Error Propagation** (Session 8) — measured how errors cascade in multi-model systems
# - [ ] **User-Centered Design** (Session 9) — shifted from "does it work?" to "can someone use it?"
# - [ ] **End-to-End System Design** (Session 10) — chose a question, a method, and built a research prototype

# %% [markdown]
# ## What I Learned
#
# **The concept that surprised me most:**
#
# ___(fill in)___
#
# **The hardest part was:**
#
# ___(fill in)___
#
# **Most useful research method** (pick one from the checklist above and say why):
#
# ___(fill in)___
#
# **What I'd investigate next** (a question you didn't get to, or a deeper version of your research question):
#
# ___(fill in)___
#
# **If I had more time, I would:**
#
# ___(fill in)___

# %% [markdown]
# ## 11 Concepts We Covered
#
# | # | Session | Concept |
# |---|---------|----------|
# | 1 | From Rules to Models | Input → Model → Output |
# | 2 | Data Collection and Representation | Training Data and Representation |
# | 3 | Data Cleaning and Feature Engineering | Adversarial Testing and the Limits of Classification |
# | 4 | Introduction to Supervised Learning | Classification vs. Generation |
# | 5 | Model Training and Parameters | Hyperparameters |
# | 6 | Model Evaluation and Generalization | Overfitting and Domain Shift |
# | 7 | Bias, Variance, and Uncertainty | Bias in AI |
# | 8 | From Single Models to Systems | Multi-Model Systems and Error Cascades |
# | 9 | Prompt Logic and Human-AI Interaction | Prompt Engineering and Human-AI Interaction |
# | 10 | Build Your Own from Scratch | Supervised Learning and Task Design |
# | 11 | Iterate and Polish | The Experimentation Loop |

# %% [markdown]
# ## GitHub Portfolio Check
#
# - [ ] Does your GitHub profile have a bio?
# - [ ] Does your `my-ai-portfolio` repo have a good README?
# - [ ] Are your notebooks uploaded?
#
# **Share your profile URL:** ___(fill in)___

# %% [markdown]
# ## What's Next?
#
# You have everything you need to keep building:
#
# - **Hugging Face**: [huggingface.co](https://huggingface.co) — browse models, build Spaces
# - **Google Colab**: [colab.research.google.com](https://colab.research.google.com) — run notebooks for free
# - **Course notebooks**: Always available on [GitHub](https://github.com/buildLittleWorlds/level-2-course-material)
#
# Keep building. Keep experimenting. Keep breaking things on purpose.
